# %%
import pandas as pd #to read the structured data
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn import preprocessing
import numpy as np
plt.figure(figsize=(20,8))


house_price_df=pd.read_csv('house price.csv')
house_price_df

house_price_df.shape

house_price_df.columns

house_price_df.describe()

type(house_price_df['LotFrontage'])

house_price_df.iloc[0] 

house_price_df.iloc[0,:4] 

house_price_df.iloc[:5,:4]

house_price_df.isnull()

house_price_df.isnull().sum() #to check the count of missing values in columns of data frame

missing_values_df=pd.DataFrame({'column_name':house_price_df.columns,'missing_values_count':house_price_df.isnull().sum(),'missing_values_percentage':house_price_df.isnull().sum()/house_price_df.shape[0]*100})

missing_values_df.sort_values(by='missing_values_percentage',ascending=False)

house_price_df.corr() #corelation
np.corrcoef(house_price_df['SalePrice'],house_price_df['LotArea']) #correlation between two variables
# Out:
# array([[1.        , 0.26384335],
#        [0.26384335, 1.        ]])

# %%
house_price_df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
int_col=[]
for naa_istam in house_price_df.columns:
    if house_price_df[naa_istam].dtype=='int64':
        int_col.append(naa_istam)

int_col

numerical_cols=[col for col in house_price_df.columns if house_price_df[col].dtype=='int64' or 'float64']

numerical_cols
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
int_col=[]
for naa_istam in house_price_df.columns:
    if house_price_df[naa_istam].dtype=='float64':
        int_col.append(naa_istam)

int_col
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
cat_cols=[col for col in house_price_df.columns if house_price_df[col].dtype=='object']
cat_cols
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
house_price_df[cat_cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0947e964fb29> in <module>
# ----> 1 house_price_df[cat_cols]
#
# NameError: name 'house_price_df' is not defined

# %%
plt.hist(house_price_df['SalePrice'])
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(house_price_df['SalePrice'])

# %%
#sns.boxplot(house_price_df['SalePrice'])

sns.boxplot(house_price_df['SalePrice'],orient='v')

# %%
house_price_df['MSZoning'].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
sns.boxplot(house_price_df['MSZoning'],house_price_df['SalePrice'])

# %%
type(house_price_df['LotFrontage'])
# Out:
# pandas.core.series.Series

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np


house_price_df=pd.read_csv('house_price_data.csv')
house_price_df.dtypes
numerical_columns_list=[]
for col in house_price_df.columns:
    if house_price_df[col].dtype=='int64' or house_price_df[col].dtype== 'float64':
        numerical_columns_list.append(col)
        
max=house_price_df[numerical_columns_list].max()
min=house_price_df[numerical_columns_list].min()
A=(house_price_df[numerical_columns_list]-min)/(max-min)
A
# Out:
#             Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0     0.000000    0.235294     0.150685  0.033420     0.666667        0.500
# 1     0.000685    0.000000     0.202055  0.038795     0.555556        0.875
# 2     0.001371    0.235294     0.160959  0.046507     0.666667        0.500
# 3     0.002056    0.294118     0.133562  0.038561     0.666667        0.500
# 4     0.002742    0.235294     0.215753  0.060576     0.777778        0.500
# 5     0.003427    0.176471     0.219178  0.059899     0.444444        0.500
# 6     0.004112    0.000000     0.184932  0.041057     0.777778        0.500
# 7     0.004798    0.235294          NaN  0.042450     0.666667        0.625
# 8     0.005483    0.176471     0.102740  0.022529     0.666667        0.500
# 9     0.006169    1.000000     0.099315  0.028605     0.444444        0.625
# 10    0.006854    0.000000     0.167808  0.046274     0.444444        0.500
# ...
